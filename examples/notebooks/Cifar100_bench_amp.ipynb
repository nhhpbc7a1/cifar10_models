# %% [markdown]
# # Benchmark mixed precision training on Cifar100
#
# In this notebook we will benchmark 1) native PyTorch mixed precision module [`torch.cuda.amp`](https://pytorch.org/docs/master/amp.html) and 2) NVidia/Apex package.
#
# We will train Wide-ResNet model on Cifar100 dataset using Turing enabled GPU and compare training times.
#
# **TL;DR**
#
# The ranking is the following:
# - 1st place: Nvidia/Apex "O2"
# - 2nd place: `torch.cuda.amp`: autocast and scaler
# - 3rd place: Nvidia/Apex "O1"
# - 4th place: fp32
#
# According to @mcarilli: "Native amp is more like a faster, better integrated, locally enabled O1"

# %% [markdown]
# ## Installations and setup
#
# 1) Recently added [`torch.cuda.amp`](https://pytorch.org/docs/master/notes/amp_examples.html#working-with-multiple-models-losses-and-optimizers) module to perform automatic mixed precision training instead of using Nvidia/Apex package is available in PyTorch >=1.6.0.
#
# In this example we only need `pynvml` and `fire` packages, assuming that `torch` and `ignite` are already installed. We can install it using pip:

# %%
# !pip install pytorch-ignite pynvml fire
# Out:
# Collecting pytorch-ignite
#   Downloading pytorch_ignite-0.5.3-py3-none-any.whl.metadata (27 kB)
# Collecting pynvml
#   Downloading pynvml-13.0.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting fire
#   Downloading fire-0.7.1-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from pytorch-ignite) (26.0)
# Requirement already satisfied: torch<3,>=1.10 in /usr/local/lib/python3.12/dist-packages (from pytorch-ignite) (2.10.0+cu128)
# Requirement already satisfied: nvidia-ml-py>=12.0.0 in /usr/local/lib/python3.12/dist-packages (from pynvml) (13.590.48)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.12/dist-packages (from fire) (3.3.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch<3,>=1.10->pytorch-ignite) (3.24.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=1.10->pytorch-ignite) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch<3,>=1.10->pytorch-ignite) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=1.10->pytorch-ignite) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=1.10->pytorch-ignite) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=1.10->pytorch-ignite) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=1.10->pytorch-ignite) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=1.10->pytorch-ignite) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=1.10->pytorch-ignite) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=1.10->pytorch-ignite) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=1.10->pytorch-ignite) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=1.10->pytorch-ignite) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=1.10->pytorch-ignite) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=1.10->pytorch-ignite) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=1.10->pytorch-ignite) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=1.10->pytorch-ignite) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=1.10->pytorch-ignite) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=1.10->pytorch-ignite) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=1.10->pytorch-ignite) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=1.10->pytorch-ignite) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=1.10->pytorch-ignite) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=1.10->pytorch-ignite) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=1.10->pytorch-ignite) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=1.10->pytorch-ignite) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch<3,>=1.10->pytorch-ignite) (1.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<3,>=1.10->pytorch-ignite) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<3,>=1.10->pytorch-ignite) (3.0.3)
# Downloading pytorch_ignite-0.5.3-py3-none-any.whl (343 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 343.8/343.8 kB 25.5 MB/s eta 0:00:00
# Downloading pynvml-13.0.1-py3-none-any.whl (28 kB)
# Downloading fire-0.7.1-py3-none-any.whl (115 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.9/115.9 kB 13.1 MB/s eta 0:00:00
# Installing collected packages: pynvml, fire, pytorch-ignite
# Successfully installed fire-0.7.1 pynvml-13.0.1 pytorch-ignite-0.5.3

# %% [markdown]
# 2) Let's install Nvidia/Apex package:

# %%
# Install Apex:
# If torch cuda version and nvcc version match:
# !pip install --upgrade --no-cache-dir --global-option="--cpp_ext" --global-option="--cuda_ext" git+https://github.com/NVIDIA/apex/
# if above command is failing, please install apex without c++/cuda extensions:
# !pip install --upgrade --no-cache-dir git+https://github.com/NVIDIA/apex/

# %%
import torch
import torchvision
import ignite
torch.__version__, torchvision.__version__, ignite.__version__

# %% [markdown]
# 3) The scripts we will execute are located in `ignite/examples/contrib/cifar100_amp_benchmark` of github repository. Let's clone the repository and setup PYTHONPATH to execute benchmark scripts:

# %%
# !git clone https://github.com/pytorch/ignite.git /tmp/ignite
scriptspath="/tmp/ignite/examples/cifar100_amp_benchmark/"
setup=f"cd {scriptspath} && export PYTHONPATH=$PWD:$PYTHONPATH"

# %% [markdown]
# 4) Download dataset

# %%
from torchvision.datasets.cifar import CIFAR100
CIFAR100(root="/tmp/cifar100/", train=True, download=True)

# %% [markdown]
# ## Training in fp32

# %%
# !{setup} && python benchmark_fp32.py /tmp/cifar100/ --batch_size=256 --max_epochs=20

# %% [markdown]
# ## Training with `torch.cuda.amp`

# %%
# !{setup} && python benchmark_torch_cuda_amp.py /tmp/cifar100/ --batch_size=256 --max_epochs=20

# %% [markdown]
# ## Training with `Nvidia/apex`
#
#
# - we check 2 optimization levels: "O1" and "O2"
#     - "O1" optimization level: automatic casts arount Pytorch functions and tensor methods
#     - "O2" optimization level: fp16 training with fp32 batchnorm and fp32 master weights

# %%
# !{setup} && python benchmark_nvidia_apex.py /tmp/cifar100/ --batch_size=256 --max_epochs=20 --opt="O1"

# %%
# !{setup} && python benchmark_nvidia_apex.py /tmp/cifar100/ --batch_size=256 --max_epochs=20 --opt="O2"
